# %% [markdown]
# # Task 1
# Assignment 1:
# Demonstrate minimum 15 basic docker command with explanation and screenshot.

# %%
1. docker images : This commands displays all the available docker images

# %%
from IPython.display import Image
Image(filename=r'C:\Users\mriyu\OneDrive\Desktop\iNeuron Projects\Docker\docker images.jpg')

# %% [markdown]
# 2. docker run : Docker run command runs the docker container and we can view the running container on the host machine by using the assigned port number.

# %%
from IPython.display import Image
Image(filename=r'C:\Users\mriyu\OneDrive\Desktop\iNeuron Projects\Docker\docker run.jpg')

# %% [markdown]
# 3. docker ps : shows all running containers

# %%
from IPython.display import Image
Image(filename=r'C:\Users\mriyu\OneDrive\Desktop\iNeuron Projects\Docker\docker ps.jpg')

# %% [markdown]
# 4. docker ps -a: displays all the containers created

# %%
from IPython.display import Image
Image(filename=r'C:\Users\mriyu\OneDrive\Desktop\iNeuron Projects\Docker\docker ps -a.jpg')

# %% [markdown]
# 5. docker stop containerID: commands stops a running container

# %%
from IPython.display import Image
Image(filename=r'C:\Users\mriyu\OneDrive\Desktop\iNeuron Projects\Docker\docker stop.jpg')

# %% [markdown]
# 6. docker stats: displays all running containers

# %%
from IPython.display import Image
Image(filename=r'C:\Users\mriyu\OneDrive\Desktop\iNeuron Projects\Docker\docker stats.jpg')

# %% [markdown]
# 7. docker pause containerID: It pauses running containers

# %%
from IPython.display import Image
Image(filename=r'C:\Users\mriyu\OneDrive\Desktop\iNeuron Projects\Docker\docker pause.jpg')

# %% [markdown]
# 8. docker unpause: this command resumes a paused container

# %%
from IPython.display import Image
Image(filename=r'C:\Users\mriyu\OneDrive\Desktop\iNeuron Projects\Docker\docker unpause.jpg')

# %% [markdown]
# 9. docker inspect containerID: displays complete inspection report of a given docker container ID in JSON format

# %%
from IPython.display import Image
Image(filename=r'C:\Users\mriyu\OneDrive\Desktop\iNeuron Projects\Docker\docker inspect.jpg')

# %% [markdown]
# 10. docker rmi imageID : removes the imageID

# %%
from IPython.display import Image
Image(filename=r'C:\Users\mriyu\OneDrive\Desktop\iNeuron Projects\Docker\docker rmi.jpg')

# %% [markdown]
# 11. docker pull repository: pulls the images from docker hub

# %%
from IPython.display import Image
Image(filename=r'C:\Users\mriyu\OneDrive\Desktop\iNeuron Projects\Docker\docker pull.jpg')

# %% [markdown]
# 12. docker tag imageID learnermp/fromibm: This command renames the pulled images from others' repositoy. We can then pushed the same in our own repository.

# %%
from IPython.display import Image
Image(filename=r'C:\Users\mriyu\OneDrive\Desktop\iNeuron Projects\Docker\docker tag.jpg')

# %% [markdown]
# 13. docker push username/dockerImge: Pushes the image to the docker registry.

# %%
from IPython.display import Image
Image(filename=r'C:\Users\mriyu\OneDrive\Desktop\iNeuron Projects\Docker\docker push.jpg')

# %% [markdown]
# 14. docker logs containerID: displays the container's output'

# %%
from IPython.display import Image
Image(filename=r'C:\Users\mriyu\OneDrive\Desktop\iNeuron Projects\Docker\docker logs.jpg')

# %% [markdown]
# 15. docker export containerid > newname.tar: saves all content of a containerid to newname.tar.

# %%
from IPython.display import Image
Image(filename=r'C:\Users\mriyu\OneDrive\Desktop\iNeuron Projects\Docker\container export1.jpg') 
Image(filename=r'C:\Users\mriyu\OneDrive\Desktop\iNeuron Projects\Docker\container export2.jpg')

# %% [markdown]
# # Assignment 2:
# ##### Hello World Docker Image Run Hello World Docker Image Locally.

# %%
from IPython.display import Image
Image(filename=r'C:\Users\mriyu\OneDrive\Desktop\iNeuron Projects\Docker\Hello-world.jpg')

# %% [markdown]
# # Assignment 3:
# #### Create a hello world fastapi application. Create a Dockerfile for your fastapi hello world application. Build Docker image using Docker file. Run docker image build in previous step. Push your Docker image to Docker Hub.

# %% [markdown]
# https://hub.docker.com/r/learnermp/mrityunjay_fastapi

# %%
from IPython.display import Image
Image(filename=r'C:\Users\mriyu\OneDrive\Desktop\iNeuron Projects\Docker\build fast API.jpg')

# %%
from IPython.display import Image
Image(filename=r'C:\Users\mriyu\OneDrive\Desktop\iNeuron Projects\Docker\fastapi_helloworld.jpg')
